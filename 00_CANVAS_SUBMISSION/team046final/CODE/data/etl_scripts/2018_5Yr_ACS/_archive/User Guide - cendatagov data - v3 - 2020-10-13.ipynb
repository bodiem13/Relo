# %% [markdown]
# ### Census Data User Guide - Version 3
#
# **2020-10-13 V3 UPDATE: New cleaning procedure was implemented. Details below**
#
# 2020-10-11 V2 UPDATE: Reproduced tables with protocol=4 for compatibility.
#
# 2020-10-11 - New 2018 5-yr census data were downloaded from data.census.gov and prepared into 3 different tables.
#
# Tables:
#
# * 2018_5yr_cendatagov_ESTIMATES_v2.pkl - Census estimates data
# * 2018_5yr_cendatagov_ESTIMATES_DD_v2.pkl - Census estimates data - data dictionary
# * 2018_5yr_cendatagov_GAZ_v2.pkl - 2018 Gazetteer data
#
#
# **IMPORTANT:** Use GEOID field (not GEO_ID) to join estimates data and gazetteer data. Both are prepared as Integers and are ready to join.
#
# **V3 Changes to Data Prep:**
#
# 1. The last iteration lazily coerced all values to numeric values. This made some potentially real data into null data. The data cleaning was updated to more appropriately clean and cast that data to numeric values.
# 2. Data for Puerto Rico were dropped (as well as a row that represented US summary data). Data is now limited to 50 states + Washington DC. The Gaz data was updated to drop these as well.
# 3. Any column where values were not already in the range [0, 100], values in that column were scaled to that range. Nulls were ignored in that process.
# 4. After this new processing, 163 columns contained only null values. These were dropped from the Estimates table. The data dict was also updated to drop these fields.
#
# ---

# %% [markdown]
# To read the tables, import pandas:

# %%
import pandas as pd

# %% [markdown]
# Here is some code to read all tables at once. Modify the path as needed.

# %%
# Read census estimates
cen_20185_estimates = pd.read_pickle('/media/school/project/data.census.gov_downloads/2018_5yr_cendatagov_ESTIMATES_v3.pkl')
cen_20185_estimates_dd = pd.read_pickle('/media/school/project/data.census.gov_downloads/2018_5yr_cendatagov_ESTIMATES_DD_v3.pkl')
# Read gazetteer file that links geography to lat/lon
cen_20185_gaz = pd.read_pickle('/media/school/project/data.census.gov_downloads/2018_5yr_cendatagov_GAZ_v3.pkl')

# %% [markdown]
# Function to display samples of data for each table:

# %%
from IPython.display import display
def show_info(df):
    print(df.info())
    display(df)

# %% [markdown]
# ---
#
# ## Data Dictionaries
#
# The following table is the data dictionary for the `estimates` data.
#
# These may be useful when e.g. deciding which data to use in the models, since the column names are not particularly descriptive. These are mostly directly from the Census template files with some minor manual modifications.

# %% [markdown]
# ### Table 1: cen_20185_estimates_dd_v3

# %%
show_info(cen_20185_estimates_dd)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1153 entries, 0 to 1152
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   column       1153 non-null   object
#  1   description  1153 non-null   object
# dtypes: object(2)
# memory usage: 18.1+ KB
# None
#               column                                        description
# 0              GEOID                       Field to Join Gazetteer Data
# 1             GEO_ID                                                 id
# 2               NAME                               Geographic Area Name
# 3        B02001_001E                                    Estimate!!Total
# 4        B02001_002E                       Estimate!!Total!!White alone
# ...              ...                                                ...
# 1148  S2405_C03_006E  Estimate!!Service occupations!!Civilian employ...
# 1149  S2405_C04_006E  Estimate!!Sales and office occupations!!Civili...
# 1150  S2405_C05_006E  Estimate!!Natural resources, construction, and...
# 1151  S2405_C06_006E  Estimate!!Production, transportation, and mate...
# 1152  S2405_C01_007E  Estimate!!Total!!Civilian employed population ...
#
# [1153 rows x 2 columns]

# %% [markdown]
# ---
#
# ## Data Tables

# %% [markdown]
# ### Table 2: cen_20185_estimates_v3
#
# This table contains the data that can be used for the clustering models.
#
# `GEOID` can be used to join Gazetteer data.

# %%
show_info(cen_20185_estimates)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73056 entries, 0 to 73055
# Columns: 1153 entries, GEOID to S2405_C02_002E
# dtypes: float64(1150), int64(1), object(2)
# memory usage: 642.7+ MB
# None
#              GEOID                GEO_ID  \
# 0      10003000400  1400000US10003000400
# 1      10003001300  1400000US10003001300
# 2      10003002600  1400000US10003002600
# 3      10003010200  1400000US10003010200
# 4      10003010300  1400000US10003010300
# ...            ...                   ...
# 73051  53063010304  1400000US53063010304
# 73052  53063010501  1400000US53063010501
# 73053  53063010601  1400000US53063010601
# 73054  53073000700  1400000US53073000700
# 73055  53073001100  1400000US53073001100
#
#                                                   NAME  B02001_002E  \
# 0          Census Tract 4, New Castle County, Delaware     3.119600
# 1         Census Tract 13, New Castle County, Delaware     7.328331
# 2         Census Tract 26, New Castle County, Delaware     2.355616
# 3        Census Tract 102, New Castle County, Delaware     3.478854
# 4        Census Tract 103, New Castle County, Delaware     4.861301
# ...                                                ...          ...
# 73051  Census Tract 103.04, Spokane County, Washington    13.080946
# 73052  Census Tract 105.01, Spokane County, Washington    17.694407
# 73053  Census Tract 106.01, Spokane County, Washington     7.919509
# 73054       Census Tract 7, Whatcom County, Washington    11.020919
# 73055      Census Tract 11, Whatcom County, Washington    14.506594
#
#        B02001_003E  B02001_008E  B02001_004E  B02001_007E  B02001_001E  \
# 0         8.768328     0.937866     0.265767     0.000000     4.173841
# 1         0.744868     1.219226     0.000000     0.000000     4.997794
# 2        12.609971     1.500586     0.000000     2.907958     4.997794
# 3         3.126100     0.633060     0.000000     0.428405     3.069545
# 4         4.862170     0.000000     0.000000     0.000000     4.582260
# ...            ...          ...          ...          ...          ...
# 73051     0.000000     1.524033     0.000000     0.000000     8.334875
# 73052     0.029326     6.354045     2.269243     0.714008    12.172874
# 73053     0.275660     6.518171     0.490647     0.311567     5.579827
# 73054     1.167155     8.440797     0.705305     7.192003     9.365172
# 73055     0.093842     5.298945     0.000000     0.324549     9.900243
#
#        B02001_006E  ...  S2405_C04_012E  S2405_C05_007E  S2405_C01_008E  \
# 0         0.000000  ...             0.0             0.0        0.775194
# 1         0.000000  ...            11.7             0.0        3.875969
# 2         0.000000  ...            31.9             0.0        0.000000
# 3         0.000000  ...             0.0            10.5        5.340224
# 4         0.000000  ...             7.7             0.0        4.478898
# ...            ...  ...             ...             ...             ...
# 73051     0.000000  ...            39.4            11.7        2.067183
# 73052     0.000000  ...            14.6             4.5        6.459948
# 73053     0.000000  ...            11.0             0.0        1.119724
# 73054     0.000000  ...             0.0            23.8        2.239449
# 73055     0.331034  ...             9.7             0.0       10.766581
#
#        S2405_C06_001E  S2405_C01_011E  S2405_C02_011E  S2405_C04_004E  \
# 0                 2.8        4.592987            69.6            56.5
# 1                 2.8        3.967603            77.0             0.0
# 2                13.5        5.033832            63.3             0.0
# 3                10.7        3.075661            60.3            31.8
# 4                10.2        3.977855            84.5             8.3
# ...               ...             ...             ...             ...
# 73051            19.7        6.561411            48.1             6.6
# 73052             7.1       11.185155            67.6             0.0
# 73053            13.0        6.161575            73.4             0.0
# 73054            12.5        9.032192            52.4             3.2
# 73055             9.6       11.482469            86.2             0.0
#
#        S2405_C04_002E  S2405_C05_008E  S2405_C02_002E
# 0               100.0             0.0             0.0
# 1                 NaN             0.0             NaN
# 2                 0.0             NaN             0.0
# 3                 0.0             0.0            62.5
# 4                 NaN             0.0             NaN
# ...               ...             ...             ...
# 73051            76.9             0.0             0.0
# 73052             0.0            37.3            10.0
# 73053             0.0            53.8             0.0
# 73054             0.0             0.0            46.2
# 73055             NaN             0.0             NaN
#
# [73056 rows x 1153 columns]

# %% [markdown]
# ### Table 3: cen_20185_gaz_v3
#
# `GEOID` can be used to join to estimates data.
#
# While a data dict was not prepared, it can be found here: https://www.census.gov/programs-surveys/geography/technical-documentation/records-layout/gaz18-record-layouts.html
#
#
# Brief overview:
#
# * USPS - State
# * GEOID - ID for tract
# * ALAND - Area of Land, m^2
# * AWATER - Area of Water, m^2
# * ALAND_SQMI - Area of Land, mi^2
# * AWATER_SQMI - Area of Water, mi^2
# * INTPTLAT - Latitude
# * INTPTLONG - Longitute

# %%
show_info(cen_20185_gaz)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73056 entries, 0 to 73055
# Data columns (total 8 columns):
#  #   Column                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                  --------------  -----
#  0   USPS                                                                                                                                    73056 non-null  object
#  1   GEOID                                                                                                                                   73056 non-null  int64
#  2   ALAND                                                                                                                                   73056 non-null  int64
#  3   AWATER                                                                                                                                  73056 non-null  int64
#  4   ALAND_SQMI                                                                                                                              73056 non-null  float64
#  5   AWATER_SQMI                                                                                                                             73056 non-null  float64
#  6   INTPTLAT                                                                                                                                73056 non-null  float64
#  7   INTPTLONG                                                                                                                               73056 non-null  float64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 4.5+ MB
# None
#       USPS        GEOID       ALAND   AWATER  ALAND_SQMI  AWATER_SQMI  \
# 0       AL   1001020100     9817813    28435       3.791        0.011
# 1       AL   1001020200     3325679     5669       1.284        0.002
# 2       AL   1001020300     5349273     9054       2.065        0.003
# 3       AL   1001020400     6384276     8408       2.465        0.003
# 4       AL   1001020500    11408869    43534       4.405        0.017
# ...    ...          ...         ...      ...         ...          ...
# 73051   WY  56043000200  5780716346  9742603    2231.947        3.762
# 73052   WY  56043000301     1993203        0       0.770        0.000
# 73053   WY  56043000302    15429213   687001       5.957        0.265
# 73054   WY  56045951100  6100010068  5041727    2355.227        1.947
# 73055   WY  56045951300   110794048   183772      42.778        0.071
#
#         INTPTLAT  \
# 0      32.481959
# 1      32.475758
# 2      32.474024
# 3      32.471030
# 4      32.458922
# ...          ...
# 73051  43.878830
# 73052  44.014369
# 73053  44.028771
# 73054  43.846213
# 73055  43.859649
#
#        INTPTLONG
# 0                                             -86.491338
# 1                                             -86.472468
# 2                                             -86.459703
# 3                                             -86.444835
# 4                                             -86.421826
# ...                                                  ...
# 73051                                        -107.669052
# 73052                                        -107.956379
# 73053                                        -107.950748
# 73054                                        -104.570020
# 73055                                        -104.244513
#
# [73056 rows x 8 columns]
